# %% [markdown]
# <a href="https://colab.research.google.com/github/YSHS-APCSP-2526/complexconditionals-python2-213417/blob/main/text_based_adventure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Requirements for text based adventure
# 1. You must have at least 2 different "paths" that are at least 4 decisions in length
# 2. Include an element of randomness (from the random library)
# 3. Include a list that is core to the text based adventure
# 4. Include a function that is called within your program that includes a while loop, and a parameter that influences a conditional statement in your function.
# 5. Commented Code.
# 6. A [digital flowchart](https://docs.google.com/document/d/1p2k3wL6gzjYWBuWxwEQptmbbOZZNsQrthlC12SNtYgY/edit?usp=sharing) that follows accepted symbols for representing code. You can use google slides or [draw.io](https://www.drawio.com/) for the flowchart.

# %%
def intro():
 response = input("You learn about a treasure hunt with 100 million est value. Do you start journey? Y or N:    ")
 return response

# %%
def choice1(response):
  if response == "yes" or response =="Y":
    print("Great, adventure awaits. You now decide to take a boat vs a plane. Boat travel has a longer travel time, but plane travel requires more fuel.")
  else:
    print("you are boring")

# %%
def choice2(response):
  response = input("Choose boat or plane")
  if response=="boat":
    print ("Arrived: Great you arrive after 1 week due to a storm, at least you have fish")
  else:
    print ("Arrived: You burn a lot of fuel hopefully you can get back home, but you arrive ahead of the storm")
  return response

# %%
def choice3(response):
  response = input("Now that you arrived, decide next steps: Go right into jungle or look at the map. Type jungle or map")
  if response== "jungle":
    print ("Great, no hesitation, let's go....uh oh you ran into a angry tiger family. Game over. ")
  else:
    print ("You see on the map there is a waterfall or cave.")
  return response

# %%
def choice4(response):
  response = input("with the goal to find the heart of the island, which do you choose? The cave is closer, but the waterfall seems closer to the middle.")
  if response=="cave":
    print ("2 mile trek to the cave- you reach a dead end")
  else:
    print ("Waterfall it is. Estimate a 5 mile trek")
  return response

# %%
def choice5(response):
  response = input("you chose waterfall: after the 5 mile trek in uneven terrain, you arrive. you notice the waterfall covers a grotto, do you ENTER or give up and go back to the CAVE ")
  if response=="enter":
    print ("you start the swim. the water is so refreshing after your hike")
  else:
    print ("okay, you walk back to the cave region then")
  return response

# %%
def choice6(response):
  response = input("You swim into a grotto with 2 paths, do you choose left or right ")
  if response=="left":
    print ("dead end- game over")
  else:
    print ("this path is rocky and uncertain")
  return response

# %%
def choice7(response):
  response = input("do you continue even though you see shipwrecks and skulls? ")
  if response=="no":
    print ("you are boring")
  else:
    print ("you persevered and you found the key to get the treasure!! When prompted type IMFMI6")
  return response

# %%
def choice7(response):
  response = input("You leave the grotto and see a tree house on the left or go right towards the shore")
  if response=="tree house":
    print ("you run into a man, which he asks you a question")
  else:
    print (" you run into a man and he asks you a question")
  return response

# %%
def responseValidator (response):
  while response !="IMFMI6":
    response = input("invalid response, please try again")
  return response
def choice7():
  response= input("you run into the the jungle guardian- he asks you for the password")
  response=responseValidator(response)
  return  response

# %%
def main():
  response = intro()
  print(response)
  choice1(response) # Removed the argument here
  if response == "Y" or response == "yes":
    choice2(response)
    choice3(response)
    if response == "jungle":
      print("GAME OVER")
    else:
      choice4(response)
      if response == "cave":
        print ("GAME OVER")
      else:
        choice5(response)
        choice6(response)
        if response == "left":
          print ("GAME OVER")
        else:
          choice7(response)
  else:
    print("GAME OVER")

# %%
main()
# Out:
# You learn about a treasure hunt with 100 million est value. Do you start journey? Y or N:    Y
# Y
# Great, adventure awaits. You now decide to take a boat vs a plane. Boat travel has a longer travel time, but plane travel requires more fuel.
# Choose boat or planeplane
# Arrived: You burn a lot of fuel hopefully you can get back home, but you arrive ahead of the storm
# Now that you arrived, decide next steps: Go right into jungle or look at the map. Type jungle or mapmap
# You see on the map there is a waterfall or cave.
# with the goal to find the heart of the island, which do you choose? The cave is closer, but the waterfall seems closer to the middle.waterfall
# Waterfall it is. Estimate a 5 mile trek
# you chose waterfall: after the 5 mile trek in uneven terrain, you arrive. you notice the waterfall covers a grotto, do you ENTER or give up and go back to the CAVE enter
# okay, you walk back to the cave region then
# You swim into a grotto with 2 paths, do you choose left or right right
#  you found the key to get the treasure. When prompted type IMFMI6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-451043146.py in <cell line: 0>()
# ----> 1 main()
#
# /tmp/ipython-input-805330709.py in main()
#      18           print ("GAME OVER")
#      19         else:
# ---> 20           choice7(response)
#      21   else:
#      22     print("GAME OVER")
#
# TypeError: choice7() takes 0 positional arguments but 1 was given

# %%
def responseValidator (response):
  while response !="yes" and response !="no":
    response = input("invalid response, please try again")
  return response

# %%
responseValidator("yes")
# Out:
# 'yes'

# %%
#def choice1():
#  response1= input("do you agree, yes no")
#  response1=responseValidator(response1)
 # return  response1
