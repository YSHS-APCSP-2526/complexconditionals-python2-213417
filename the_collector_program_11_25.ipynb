# %% [markdown]
# <a href="https://colab.research.google.com/github/YSHS-APCSP-2526/complexconditionals-python2-213417/blob/main/the_collector_program_11_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
List= []
while True:
  response= input("Do you want to add an item?")
  if response=="yes":
       add_item= input ("What would you like to add?")
       print (add_item + " successfully stored")
       List.append(add_item)
  else:
       print (List)
       break
# Out:
# Do you want to add an item?yes
# What would you like to add?ih
# ih successfully stored
# Do you want to add an item?no
# ['ih']

# %%
sampleList= []
response= input("Do you want to add an item?")
while response == "yes":
  add_item= input ("What would you like to add?")
  print(add_item + " successfully stored")
  sampleList.append(add_item)
  response = input("Do you want to add another item?")

print("You collected: ")
for i in sampleList:
  print(i)
# Out:
# Do you want to add an item?yes
# What would you like to add?nodfha
# nodfha successfully stored
# Do you want to add another item?yes
# What would you like to add?no
# no successfully stored
# Do you want to add another item?no
# You collected:
# nodfha
# no

# %%
def popularLetter("letter1","letter2","word")
user_input=input("Please type 2 letters followed by a word.")
# Out:
#   File "/tmp/ipython-input-2443365521.py", line 1
#     def popularLetter("letter1","letter2","word")
#                       ^
# SyntaxError: invalid syntax
